# %%
from os.path import expanduser
import os

import pandas as pd
from pyarrow import parquet as pq
from datatable import dt, f
from alpha_vantage.timeseries import TimeSeries
from zlogin import fetch_access_token, fetch_kiteconnect_instance, fetch_kiteticker_instance
from kiteconnect import KiteConnect

# %% [markdown]
# # Get Zerodha, AlphaVantage Access Points

# %%
with open(expanduser('~/.tradesecrets'), 'r') as file:
    env_vars = [line.strip().split('=') for line in file.readlines()]

for pair in env_vars:
    key, value = pair
    os.environ[key] = value

ALPHAVANTAGE_API_KEY = os.environ['ALPHA_KEY']

ts = TimeSeries(key=ALPHAVANTAGE_API_KEY, output_format='pandas')
kite = fetch_kiteconnect_instance()
# Out:
# Access Token Returned!

# %% [markdown]
# # Zerodha Instruments

# %%
all_instruments = kite.instruments()

# %% [markdown]
# # Explore instruments from Zerodha

# %%
instruments = dt.Frame(list(map(
        lambda x: {k: v if v != '' else None for k, v in x.items()}, all_instruments))
    )
instruments
# Out:
# <Frame#13085a810 101565x12>

# %%
instruments.shape, list(zip(instruments.names, map(str,instruments.types)))
# Out:
# ((101006, 12),
#  [('instrument_token', 'Type.int32'),
#   ('exchange_token', 'Type.str32'),
#   ('tradingsymbol', 'Type.str32'),
#   ('name', 'Type.str32'),
#   ('last_price', 'Type.float64'),
#   ('expiry', 'Type.date32'),
#   ('strike', 'Type.float64'),
#   ('tick_size', 'Type.float64'),
#   ('lot_size', 'Type.int32'),
#   ('instrument_type', 'Type.str32'),
#   ('segment', 'Type.str32'),
#   ('exchange', 'Type.str32')])

# %%
instruments[:, dt.count(), dt.by(f['exchange'], f.segment, f.instrument_type)]#.to_pandas().to_clipboard()
# Out:
# <Frame#137fb74b0 18x4>

# %%
instruments[f.segment == 'NFO-FUT',:][:,dt.count(),dt.by(f.name)][:,:,dt.sort(-f.count)]
# Out:
# <Frame#137fb7690 198x2>

# %%
instruments[(f.segment == 'NFO-OPT') & (f.name=='NIFTY'),:][:,dt.count(),dt.by('expiry')]
# Out:
# <Frame#137fb76f0 21x2>

# %%
instruments[(f.exchange == 'NSE') & (f.segment=='INDICES'),:][:,['name','tradingsymbol']]
# Out:
# <Frame#13157f510 72x2>

# %%
futures_underlying = instruments[f.segment == 'NFO-FUT',:]['name'][0,:, dt.by('name')].to_list()[0]
current_underlying = instruments[(f.exchange == 'NSE') #& (f.name != None)
                                , :][:, f['tradingsymbol']][0, :, dt.by('tradingsymbol')].to_list()[0]
subset = set(futures_underlying) - set(current_underlying)

# %%
instruments[(f.segment == 'NFO-FUT') &
            ((f.name == 'FINNIFTY') | (f.tradingsymbol == 'NIFTY')), :]
# Out:
# <Frame#1342b2db0 3x12>

# %%
instruments[f.segment == 'INDICES', [
    "instrument_token", "exchange_token", "tradingsymbol", "name", "instrument_type", "segment", "exchange"]]
# Out:
# <Frame#1342b2870 128x7>

# %% [markdown]
# # All Futures in NFO

# %%
nfo_fut_data = instruments[f.segment=='NFO-FUT',f[:].extend({"underlying": f.name}).remove([f.strike, f.last_price, f.name])]
futures_underlying = nfo_fut_data['underlying'][0, :, dt.by('underlying')].to_list()[0]
print(f"Futures NFO Underlyings: {len(futures_underlying)}")
nfo_fut_data.head(3)
# Out:
# Futures NFO Underlyings: 198
# <Frame#137fb7ed0 3x10>

# %%
nse_equity_data = instruments[(f.segment == 'NSE') & (f.exchange == 'NSE') & (f.name != None), [
    "instrument_token", "exchange_token", "tradingsymbol", "name", "instrument_type", "segment", "exchange"]]

# %%
nse_equity_data['futures_underlying'] = f.tradingsymbol

equities = nse_equity_data[0,'tradingsymbol', dt.by('tradingsymbol')].to_list()[0]
print(f"NSE Equities: {len(equities)}")
missing_futures_underlying = set(futures_underlying)-set(equities)
print("Missing Futures", missing_futures_underlying)
nse_equity_data.head(3)

# %%
indices_mapping = {
    'NIFTY 50': 'NIFTY',
    'NIFTY BANK': 'BANKNIFTY',
    'NIFTY MID SELECT': 'MIDCPNIFTY',
    'NIFTY FIN SERVICE': 'FINNIFTY',
}

index_include_list = [
    'NIFTY 50', 'NIFTY 500', 'INDIA VIX',
    'NIFTY BANK', 'NIFTY COMMODITIES', 'NIFTY FIN SERVICE', 'NIFTY IT', 'NIFTY INFRA',
    'NIFTY MEDIA', 'NIFTY METAL', 'NIFTY MID SELECT', 'NIFTY OIL AND GAS',
    'NIFTY PHARMA', 'NIFTY PSU BANK', 'NIFTY PSE', 'NIFTY REALTY', 'NIFTY SMLCAP 250', 'NIFTY IND DIGITAL',
    'NIFTY HEALTHCARE', 'NIFTY FMCG'
]

# len(index_include_list), len(set(index_include_list))

# %%
nse_index_data = instruments[(f.segment == 'INDICES') & (f.exchange == 'NSE') & (f.name != None), [
        "instrument_token", "exchange_token", "tradingsymbol", "name", "instrument_type", "segment", "exchange"
        ]
    ]

index_inclusions = dt.Frame(tradingsymbol=index_include_list, dummy=[
                            1]*len(index_include_list))
index_inclusions.key = 'tradingsymbol'
nse_index_data = nse_index_data[:, :, dt.join(index_inclusions)][~dt.isna(
    f.dummy), f[:].remove(f.dummy)]

nse_index_data['futures_underlying'] = nse_index_data['tradingsymbol'].to_pandas(
        )['tradingsymbol'].apply(lambda x: indices_mapping.get(x, None))

nse_index_data[~dt.isna(f.futures_underlying),:].head(3)
# Out:
# <Frame#10f3303f0 3x8>

# %%
nfo_opt_data = instruments[f.segment == 'NFO-OPT', f[:].extend(
    {"underlying": f.name}).remove([f.last_price, f.name])]
options_underlying = nfo_opt_data['underlying'][0, :, dt.by('underlying')].to_list()[
    0]
print(f"Options NFO Underlyings: {len(options_underlying)}")
nfo_opt_data.head(3)
# Out:
# Options NFO Underlyings: 198
# <Frame#10bc7f9f0 3x11>

# %%
options_include_list = [
    'NIFTY', 
    'BANKNIFTY',
    'ADANIENT',
    'ADANIPORTS',
    #  'AUROPHARMA',
    #  'AXISBANK',
    #  'BAJAJFINSV',
    #  'BAJFINANCE',
    #  'BHARTIARTL',
    #  'DIVISLAB',
    #  'DLF',
    #  'DRREDDY',
    #  'HDFC',
    #  'HDFCBANK',
    #  'ICICIBANK',
    #  'INFY',
    #  'JINDALSTEL',
    #  'JSWSTEEL',
    #  'JUBLFOOD',
    #  'KOTAKBANK',
    #  'L&TFH',
    #  'LALPATHLAB',
    #  'MARUTI',
    #  'RELIANCE',
    #  'SBIN',
    #  'TCS',
 ]

options_inclusions = dt.Frame(underlying=options_include_list, dummy=[
                            1]*len(options_include_list))
options_inclusions.key = 'underlying'
nfo_opt_data = nfo_opt_data[:, :, dt.join(options_inclusions)][~dt.isna(
    f.dummy), f[:].remove(f.dummy)]
nfo_opt_data
# Out:
# <Frame#12d7676c0 4839x11>

# %%
from datetime import date, timedelta

today = date.today()
yesterday = date.today() - timedelta(days=1)
START_DATE = date.today() - timedelta(days=365*25)

print(START_DATE, yesterday)
dictionary = {
    'instrument_token': '738561',
    'from_date': date(2000,1,1),
    'to_date': date(2004,12,31),
    'interval': 'day',
    # 'continuous': True,
    'oi': True,
}
kite.historical_data(**dictionary)
# Out:
# 1997-10-04 2022-09-27
# ---------------------------------------------------------------------------
# InputException                            Traceback (most recent call last)
# /var/folders/dn/d1kkpq_10w9747y6j9py79h00000gn/T/ipykernel_2654/3282437008.py in <cell line: 16>()
#      14     'oi': True,
#      15 }
# ---> 16 kite.historical_data(**dictionary)
#
# ~/Library/Caches/pypoetry/virtualenvs/indian-stock-extract-x6TWrUnA-py3.9/lib/python3.9/site-packages/kiteconnect/connect.py in historical_data(self, instrument_token, from_date, to_date, interval, continuous, oi)
#     625         to_date_string = to_date.strftime(date_string_format) if type(to_date) == datetime.datetime else to_date
#     626
# --> 627         data = self._get("market.historical",
#     628                          url_args={"instrument_token": instrument_token, "interval": interval},
#     629                          params={
#
# ~/Library/Caches/pypoetry/virtualenvs/indian-stock-extract-x6TWrUnA-py3.9/lib/python3.9/site-packages/kiteconnect/connect.py in _get(self, route, url_args, params, is_json)
#     840     def _get(self, route, url_args=None, params=None, is_json=False):
#     841         """Alias for sending a GET request."""
# --> 842         return self._request(route, "GET", url_args=url_args, params=params, is_json=is_json)
#     843
#     844     def _post(self, route, url_args=None, params=None, is_json=False, query_params=None):
#
# ~/Library/Caches/pypoetry/virtualenvs/indian-stock-extract-x6TWrUnA-py3.9/lib/python3.9/site-packages/kiteconnect/connect.py in _request(self, route, method, url_args, params, is_json, query_params)
#     916                 # native Kite errors
#     917                 exp = getattr(ex, data.get("error_type"), ex.GeneralException)
# --> 918                 raise exp(data["message"], code=r.status_code)
#     919
#     920             return data["data"]
#
# InputException: interval exceeds limit: 2000 days

# %%
kite.ohlc('NSE:RELIANCE')
# Out:
# {'NSE:RELIANCE': {'instrument_token': 738561,
#   'last_price': 2332.45,
#   'ohlc': {'open': 2360.35, 'high': 2378, 'low': 2327.1, 'close': 2396.25}}}

# %%
data = kite.ohlc('NSE:RELIANCE')

# %%
df = pd.DataFrame.from_records(data)

# %%
df.sort_values('date')
# Out:
#                           date    open    high     low   close     volume  oi
# 0    2000-01-03 00:00:00+05:30   45.72   48.45   45.72   48.45   23150255   0
# 1    2000-01-04 00:00:00+05:30   49.74   52.33   48.38   52.33   49287678   0
# 2    2000-01-05 00:00:00+05:30   49.41   55.42   49.41   54.38  139395761   0
# 3    2000-01-06 00:00:00+05:30   55.63   57.88   55.63   56.66   81466421   0
# 4    2000-01-07 00:00:00+05:30   56.79   61.20   56.40   60.55  103225855   0
# ...                        ...     ...     ...     ...     ...        ...  ..
# 1252 2004-12-27 00:00:00+05:30  100.10  105.30   97.47   99.51   96810821   0
# 1253 2004-12-28 00:00:00+05:30  100.09  101.83   99.83  101.55   39878332   0
# 1254 2004-12-29 00:00:00+05:30  101.87  103.71  101.37  102.31   36002894   0
# 1255 2004-12-30 00:00:00+05:30  102.80  103.73  100.33  100.70   35049449   0
# 1256 2004-12-31 00:00:00+05:30  102.27  103.15  101.18  102.74   24842769   0
#
# [1257 rows x 7 columns]

# %%
nse_equity_data[f.tradingsymbol == 'RELIANCE',:]
# Out:
# <Frame#130e97960 1x7>

# %%
nse_equity_data['tradingsymbol'].to_list()[0]
# Out:
# ['20MICRONS',
#  '21STCENMGM',
#  '3IINFOLTD',
#  '3MINDIA',
#  '3PLAND',
#  '4THDIM',
#  '5PAISA',
#  '63MOONS',
#  'A2ZINFRA',
#  'AAKASH',
#  'AAREYDRUGS',
#  'AARON-BE',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'AARTISURF',
#  'AARVEEDEN',
#  'AARVI',
#  'AAVAS',
#  'ABAN',
#  'ABB',
#  'ABBOTINDIA',
#  'ABCAPITAL',
#  'ABFRL',
#  'ABMINTLLTD-BE',
#  'ABSLAMC',
#  'ABSLBAINAV',
#  'ABSLBANETF',
#  'ABSLNN50ET',
#  'ABSLNNINAV',
#  'ACC',
#  'ACCELYA',
#  'ACCURACY',
#  'ACE',
#  'ACRYSIL',
#  'ADANIENT',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'ADANIPOWER-BE',
#  'ADANITRANS',
#  'ADFFOODS',
#  'ADL-BE',
#  'ADORWELD',
#  'ADROITINFO',
#  'ADSL',
#  'ADVANIHOTR',
#  'ADVENZYMES',
#  'AEGISCHEM',
#  'AETHER',
#  'AFFLE',
#  'AGARIND',
#  'AGI',
#  'AGRITECH',
#  'AGROPHOS',
#  'AGSTRA',
#  'AHLADA-BE',
#  'AHLEAST-BE',
#  'AHLUCONT',
#  'AIAENG',
#  'AIRAN',
#  'AIROLAM',
#  'AJANTPHARM',
#  'AJMERA',
#  'AJOONI',
#  'AJRINFRA',
#  'AKASH',
#  'AKG-BE',
#  'AKSHAR',
#  'AKSHARCHEM',
#  'AKSHOPTFBR',
#  'AKZOINDIA',
#  'ALANKIT',
#  'ALBERTDAVD',
#  'ALEMBICLTD',
#  'ALICON',
#  'ALKALI',
#  'ALKEM',
#  'ALKYLAMINE',
#  'ALLCARGO',
#  'ALLSEC',
#  'ALMONDZ',
#  'ALOKINDS-BE',
#  'ALPA',
#  'ALPHAGEO',
#  'ALPSINDUS',
#  'AMARAJABAT',
#  'AMBER',
#  'AMBICAAGAR-BE',
#  'AMBIKCO',
#  'AMBUJACEM',
#  'AMDIND-BE',
#  'AMIORG',
#  'AMJLAND',
#  'AMRUTANJAN',
#  'ANANDRATHI',
#  'ANANTRAJ',
#  'ANDHRAPAP',
#  'ANDHRSUGAR',
#  'ANDREWYU',
#  'ANGELONE',
#  'ANIKINDS',
#  'ANKITMETAL',
#  'ANMOL',
#  'ANSALAPI-BE',
#  'ANSALHSG',
#  'ANTGRAPHIC',
#  'ANUP',
#  'ANURAS',
#  'APARINDS',
#  'APCL',
#  'APCOTEXIND',
#  'APEX',
#  'APLAPOLLO',
#  'APLLTD',
#  'APOLLO',
#  'APOLLOHOSP',
#  'APOLLOPIPE',
#  'APOLLOTYRE',
#  'APOLSINHOT',
#  'APTECHT',
#  'APTUS',
#  'ARCHIDPLY',
#  'ARCHIES',
#  'ARENTERP',
#  'ARIES',
#  'ARIHANTCAP',
#  'ARIHANTSUP',
#  'ARMANFIN',
#  'AROGRANITE',
#  'ARROWGREEN-BE',
#  'ARSHIYA',
#  'ARSSINFRA-BE',
#  'ARTEMISMED',
#  'ARTNIRMAN',
#  'ARVEE',
#  'ARVIND',
#  'ARVINDFASN',
#  'ARVSMART',
#  'ASAHIINDIA',
#  'ASAHISONG',
#  'ASAL',
#  'ASALCBR',
#  'ASHAPURMIN',
#  'ASHIANA',
#  'ASHIMASYN',
#  'ASHOKA',
#  'ASHOKLEY',
#  'ASIANENE',
#  'ASIANHOTNR',
#  'ASIANPAINT',
#  'ASIANTILES',
#  'ASPINWALL',
#  'ASTEC',
#  'ASTERDM',
#  'ASTRAL',
#  'ASTRAMICRO',
#  'ASTRAZEN',
#  'ASTRON',
#  'ATFL',
#  'ATGL',
#  'ATLANTA',
#  'ATUL',
#  'ATULAUTO',
#  'AUBANK',
#  'AURIONPRO',
#  'AUROPHARMA',
#  'AURUM-BE',
#  'AUSOMENT',
#  'AUTOAXLES',
#  'AUTOBEES',
#  'AUTOBEINAV',
#  'AUTOIND',
#  'AVADHSUGAR',
#  'AVANTIFEED',
#  'AVROIND',
#  'AVTNPL',
#  'AWHCL',
#  'AWL',
#  'AXISBANK',
#  'AXISBNINAV',
#  'AXISBNKETF',
#  'AXISBPINAV',
#  'AXISBPSETF',
#  'AXISCADES',
#  'AXISCEINAV',
#  'AXISCETF',
#  'AXISGOINAV',
#  'AXISGOLD',
#  'AXISHCETF',
#  'AXISHCINAV',
#  'AXISILINAV',
#  'AXISILVER',
#  'AXISNIFTY',
#  'AXISNIINAV',
#  'AXISTECETF',
#  'AXISTEINAV',
#  'AXITA',
#  'AYMSYNTEX',
#  'BAFNAPH-BE',
#  'BAGFILMS-BE',
#  'BAJAJ-AUTO',
#  'BAJAJCON',
#  'BAJAJELEC',
#  'BAJAJFINSV',
#  'BAJAJHCARE',
#  'BAJAJHIND',
#  'BAJAJHLDNG',
#  'BAJFINANCE',
#  'BALAJITELE',
#  'BALAMINES',
#  'BALAXI-BE',
#  'BALKRISHNA',
#  'BALKRISIND',
#  'BALMLAWRIE',
#  'BALPHARMA',
#  'BALRAMCHIN',
#  'BANARBEADS',
#  'BANARISUG',
#  'BANCOINDIA',
#  'BANDHANBNK',
#  'BANG',
#  'BANKA',
#  'BANKBARODA',
#  'BANKBEES',
#  'BANKINDIA',
#  'BANSWRAS',
#  'BARBEQUE',
#  'BASF',
#  'BASML',
#  'BATAINDIA',
#  'BAYERCROP',
#  'BBETF0432',
#  'BBETF0INAV',
#  'BBL',
#  'BBOX',
#  'BBTC',
#  'BCG',
#  'BCLIND',
#  'BCONCEPTS-BE',
#  'BCP',
#  'BDL',
#  'BEARDSELL',
#  'BECTORFOOD',
#  'BEDMUTHA',
#  'BEL',
#  'BEML',
#  'BEPL',
#  'BERGEPAINT',
#  'BESTAGRO',
#  'BFINVEST',
#  'BFUTILITIE',
#  'BGRENERGY',
#  'BHAGCHEM',
#  'BHAGERIA',
#  'BHAGYANGR',
#  'BHAGYAPROP',
#  'BHANDARI',
#  'BHARATFORG',
#  'BHARATGEAR',
#  'BHARATRAS',
#  'BHARATWIRE',
#  'BHARTIARTL',
#  'BHEL',
#  'BIGBLOC-BE',
#  'BIL',
#  'BINDALAGRO',
#  'BIOCON',
#  'BIOFILCHEM',
#  'BIRLACABLE',
#  'BIRLACORPN',
#  'BIRLAMONEY',
#  'BLBLIMITED',
#  'BLISSGVS',
#  'BLKASHYAP',
#  'BLS',
#  'BLUECOAST-BE',
#  'BLUEDART',
#  'BLUESTARCO',
#  'BODALCHEM',
#  'BOMDYEING',
#  'BOROLTD',
#  'BORORENEW',
#  'BOSCHLTD',
#  'BPCL',
#  'BPL',
#  'BRIGADE',
#  'BRITANNIA',
#  'BRNL',
#  'BROOKS-BE',
#  'BSE',
#  'BSHSL',
#  'BSL',
#  'BSLGOLDETF',
#  'BSLGOLINAV',
#  'BSLNIFINAV',
#  'BSLNIFTY',
#  'BSLSENETFG',
#  'BSLSENINAV',
#  'BSOFT',
#  'BURNPUR',
#  'BUTTERFLY',
#  'BVCL-BE',
#  'BYKE',
#  'CALSOFT',
#  'CAMLINFINE',
#  'CAMPUS',
#  'CAMS',
#  'CANBK',
#  'CANFINHOME',
#  'CANTABIL',
#  'CAPACITE',
#  'CAPLIPOINT',
#  'CAPTRUST',
#  'CARBORUNIV',
#  'CAREERP',
#  'CARERATING',
#  'CARTRADE',
#  'CASTROLIND',
#  'CCCL-BE',
#  'CCHHL-BE',
#  'CCL',
#  'CDSL',
#  'CEATLTD',
#  'CELEBRITY',
#  'CENTENKA',
#  'CENTEXT-BE',
#  'CENTRALBK',
#  'CENTRUM',
#  'CENTUM',
#  'CENTURYPLY',
#  'CENTURYTEX',
#  'CERA',
#  'CEREBRAINT',
#  'CESC',
#  'CGCL',
#  'CGPOWER',
#  'CHALET',
#  'CHAMBLFERT',
#  'CHEMBOND',
#  'CHEMCON',
#  'CHEMFAB',
#  'CHEMPLASTS',
#  'CHENNPETRO',
#  'CHEVIOT',
#  'CHOICEIN',
#  'CHOLAFIN',
#  'CHOLAHLDNG',
#  'CIGNITITEC',
#  'CINELINE',
#  'CINEVISTA',
#  'CIPLA',
#  'CLEAN',
#  'CLEDUCATE',
#  'CLNINDIA',
#  'CLSEL',
#  'CMICABLES',
#  'CMSINFO',
#  'COALINDIA',
#  'COASTCORP',
#  'COCHINSHIP',
#  'COFFEEDAY',
#  'COFORGE',
#  'COLPAL',
#  'COMPINFO',
#  'COMPUSOFT',
#  'CONCOR',
#  'CONFIPET',
#  'CONSOFINVT',
#  'CONSUMBEES',
#  'CONTROLPR',
#  'CORALFINAC',
#  'CORDSCABLE',
#  'COROMANDEL',
#  'COSMOFIRST',
#  'COUNCODOS',
#  'CPSEETF',
#  'CRAFTSMAN',
#  'CREATIVE',
#  'CREATIVEYE',
#  'CREDITACC',
#  'CREST',
#  'CRISIL',
#  'CROMPTON',
#  'CROWN',
#  'CSBBANK',
#  'CSLFINANCE',
#  'CTE',
#  'CUB',
#  'CUBEXTUB',
#  'CUMMINSIND',
#  'CUPID',
#  'CYBERMEDIA',
#  'CYBERTECH',
#  'CYIENT',
#  'DAAWAT',
#  'DABUR',
#  'DALBHARAT',
#  'DALMIASUG',
#  'DAMODARIND',
#  'DANGEE',
#  'DATAMATICS',
#  'DATAPATTNS',
#  'DBCORP',
#  'DBL',
#  'DBOL',
#  'DBREALTY',
#  'DBSTOCKBRO',
#  'DCAL',
#  'DCBBANK',
#  'DCM',
#  'DCMFINSERV-BE',
#  'DCMNVL',
#  'DCMSHRIRAM',
#  'DCMSRIND',
#  'DCW',
#  'DECCANCE',
#  'DEEPAKFERT',
#  'DEEPAKNTR',
#  'DEEPENR',
#  'DEEPINDS',
#  'DELHIVERY',
#  'DELPHIFX',
#  'DELTACORP',
#  'DELTAMAGNT',
#  'DEN',
#  'DENORA',
#  'DEVIT',
#  'DEVYANI',
#  'DFMFOODS',
#  'DGCONTENT',
#  'DHAMPURSUG',
#  'DHANBANK',
#  'DHANI',
#  'DHANUKA',
#  'DHARAMSI',
#  'DHARSUGAR-BE',
#  'DHRUV',
#  'DHUNINV',
#  'DIAMONDYD',
#  'DICIND',
#  'DIGISPICE',
#  'DIL',
#  'DISHTV',
#  'DIVISLAB',
#  'DIVOPPBEES',
#  'DIXON',
#  'DLF',
#  'DLINKINDIA',
#  'DMART',
#  'DNAMEDIA',
#  'DODLA',
#  'DOLATALGO',
#  'DOLLAR',
#  'DONEAR',
#  'DPABHUSHAN',
#  'DPSCLTD',
#  'DPWIRES',
#  'DRCSYSTEMS-BE',
#  'DREAMFOLKS',
#  'DREDGECORP',
#  'DRREDDY',
#  'DSPN50ETF',
#  'DSPN50INAV',
#  'DSPNEWETF',
#  'DSPNEWINAV',
#  'DSPQ50ETF',
#  'DSPQ50INAV',
#  'DSPSILINAV',
#  'DSPSILVETF',
#  'DSSL',
#  'DTIL',
#  'DUCON',
#  'DVL',
#  'DWARKESH',
#  'DYCL',
#  'DYNAMATECH',
#  'DYNPRO',
#  'E2E-BE',
#  'EASEMYTRIP',
#  'EASTSILK-BE',
#  'EBANK',
#  'EBANKINAV',
#  'EBBE23INAV',
#  'EBBE30INAV',
#  'EBBE31INAV',
#  'EBBE32INAV',
#  'EBBETF0423',
#  'EBBETF0425',
#  'EBBETF0430',
#  'EBBETF0431',
#  'ECLERX',
#  'EDELWEISS',
#  'EICHERMOT',
#  'EIDPARRY',
#  'EIFFL',
#  'EIHAHOTELS',
#  'EIHOTEL',
#  'EIMCOELECO',
#  'EKC',
#  'ELDEHSG',
#  'ELECON',
#  'ELECTCAST',
#  'ELECTHERM',
#  'ELGIEQUIP',
#  'ELGIRUBCO',
#  'EMAMILTD',
#  'EMAMIPAP',
#  'EMAMIREAL',
#  'EMKAY',
#  'EMMBI',
#  'EMUDHRA',
#  'ENDURANCE',
#  'ENERGYDEV',
#  'ENGINERSIN',
#  'ENIL',
#  'EPL',
#  'EQUITAS',
#  'EQUITASBNK',
#  'ERIS',
#  'EROSMEDIA-BE',
#  'ESABINDIA',
#  'ESCORTS',
#  'ESSARSHPNG',
#  'ESSENTIA',
#  'ESTER',
#  'ETHOSLTD',
#  'EUROTEXIND',
#  'EVEREADY',
#  'EVERESTIND',
#  'EXCEL',
#  'EXCELINDUS',
#  'EXIDEIND',
#  'EXPLEOSOL',
#  'EXXARO',
#  'FACT',
#  'FAIRCHEMOR',
#  'FCL',
#  'FCONSUMER-BE',
#  'FCSSOFT',
#  'FDC',
#  'FEDERALBNK',
#  'FEL-BE',
#  'FELDVR-BE',
#  'FIBERWEB',
#  'FIEMIND',
#  'FILATEX',
#  'FINCABLES',
#  'FINEORG',
#  'FINOPB',
#  'FINPIPE',
#  'FLEXITUFF',
#  'FLFL-BE',
#  'FLUOROCHEM',
#  'FMGOETZE',
#  'FMNL',
#  'FOCUS',
#  'FOODSIN',
#  'FORCEMOT',
#  'FORTIS',
#  'FOSECOIND',
#  'FSC',
#  'FSL',
#  'GABRIEL',
#  'GAEL',
#  'GAIL',
#  'GAL',
#  'GALAXYSURF',
#  'GALLANTT',
#  'GANDHITUBE',
#  'GANECOS',
#  'GANESHBE',
#  'GANESHHOUC',
#  'GANGAFORGE',
#  'GANGESSECU',
#  'GARFIBRES',
#  'GATEWAY',
#  'GATI',
#  'GAYAHWS-BE',
#  'GAYAPROJ',
#  'GEECEE',
#  'GEEKAYWIRE',
#  'GENCON',
#  'GENESYS-BE',
#  'GENUSPAPER',
#  'GENUSPOWER',
#  'GEOJITFSL',
#  'GEPIL',
#  'GESHIP',
#  'GET&D',
#  'GFLLIMITED',
#  'GFSTEELS-BE',
#  'GHCL',
#  'GICHSGFIN',
#  'GICRE',
#  'GILLANDERS',
#  'GILLETTE',
#  'GILT5YBEES',
#  'GILT5YINAV',
#  'GINNIFILA',
#  'GIPCL',
#  'GKWLIMITED',
#  'GLAND',
#  'GLAXO',
#  'GLENMARK',
#  'GLFL-BE',
#  'GLOBAL',
#  'GLOBALVECT',
#  'GLOBE',
#  'GLOBUSSPR',
#  'GLS',
#  'GMBREW',
#  'GMDCLTD',
#  'GMMPFAUDLR',
#  'GMRINFRA',
#  'GMRP&UI',
#  'GNA',
#  'GNFC',
#  'GOACARBON',
#  'GOCLCORP',
#  'GOCOLORS',
#  'GODFRYPHLP',
#  'GODHA',
#  'GODREJAGRO',
#  'GODREJCP',
#  'GODREJIND',
#  'GODREJPROP',
#  'GOKEX',
#  'GOKUL',
#  'GOKULAGRO',
#  'GOLDBEES',
#  'GOLDBEINAV',
#  'GOLDENTOBC-BE',
#  'GOLDIAM',
#  'GOLDSHARE',
#  'GOLDSHINAV',
#  'GOLDTECH',
#  'GOODLUCK',
#  'GOODYEAR',
#  'GPIL',
#  'GPPL',
#  'GPTINFRA',
#  'GRANULES',
#  'GRAPHITE',
#  'GRASIM',
#  'GRAUWEIL',
#  'GRAVITA',
#  'GREAVESCOT',
#  'GREENLAM',
#  'GREENPANEL',
#  'GREENPLY',
#  'GREENPOWER',
#  'GRINDWELL',
#  'GRINFRA',
#  'GRMOVER',
#  'GROBTEA',
#  'GRPLTD',
#  'GRSE',
#  'GRWRHITECH',
#  'GSCLCEMENT',
#  'GSFC',
#  'GSPL',
#  'GSS',
#  'GTL',
#  'GTLINFRA',
#  'GTPL',
#  'GUFICBIO',
#  'GUJALKALI',
#  'GUJAPOLLO',
#  'GUJGASLTD',
#  'GUJRAFFIA-BE',
#  'GULFOILLUB',
#  'GULFPETRO',
#  'GULPOLY',
#  'GVKPIL-BE',
#  'HAL',
#  'HAPPSTMNDS',
#  'HARDWYN',
#  'HARIOMPIPE',
#  'HARRMALAYA',
#  'HARSHA',
#  'HATHWAY',
#  'HATSUN',
#  'HAVELLS',
#  'HAVISHA-BE',
#  'HBANKEINAV',
#  'HBANKETF',
#  'HBLPOWER',
#  'HBSL',
#  'HCC',
#  'HCG',
#  'HCL-INSYS',
#  'HCLTECH',
#  'HDF100INAV',
#  'HDFC',
#  'HDFC50INAV',
#  'HDFCAMC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HDFCMFGETF',
#  'HDFCMFINAV',
#  'HDFCNEXT50',
#  'HDFCNIF100',
#  'HDFCNIFETF',
#  'HDFCNIINAV',
#  'HDFCSEINAV',
#  'HDFCSENETF',
#  'HDFCSIINAV',
#  'HDFCSILVER',
#  'HEADSUP',
#  'HEALTHINAV',
#  'HEALTHY',
#  'HECPROJECT',
#  'HEG',
#  'HEIDELBERG',
#  'HEMIPROP',
#  'HERANBA',
#  'HERCULES',
#  'HERITGFOOD',
#  'HEROMOTOCO',
#  'HESTERBIO',
#  'HEXATRADEX',
#  'HFCL',
#  'HGINFRA',
#  'HGS',
#  'HIKAL',
#  'HIL',
#  'HILTON',
#  'HIMATSEIDE',
#  'HINDALCO',
#  'HINDCOMPOS',
#  'HINDCON',
#  'HINDCOPPER',
#  'HINDMOTORS',
#  'HINDOILEXP',
#  'HINDPETRO',
#  'HINDUNILVR',
#  'HINDWAREAP',
#  'HINDZINC',
#  'HIRECT',
#  'HISARMETAL',
#  'HITECH',
#  'HITECHCORP',
#  'HITECHGEAR',
#  'HLEGLAS',
#  'HLVLTD',
#  'HMVL',
#  'HNDFDS',
#  'HNGSNGBEES',
#  'HOMEFIRST',
#  'HONAUT',
#  'HONDAPOWER',
#  'HOVS',
#  'HPAL',
#  'HPL',
#  'HSCL',
#  'HTMEDIA',
#  'HUBTOWN-BE',
#  'HUDCO',
#  'HUHTAMAKI',
#  'IBMFNIFTY',
#  'IBMFNIINAV',
#  'IBREALEST',
#  'IBULHSGFIN',
#  'ICDSLTD-BE',
#  'ICEMAKE-BE',
#  'ICICI1INAV',
#  'ICICI2INAV',
#  'ICICI500',
#  'ICICI5GSEC',
#  'ICICI5INAV',
#  'ICICIAINAV',
#  'ICICIALPLV',
#  'ICICIAUTO',
#  'ICICIB22',
#  'ICICIBANK',
#  'ICICIBANKN',
#  'ICICIBANKP',
#  'ICICIBINAV',
#  'ICICICINAV',
#  'ICICICONSU',
#  'ICICIFINAV',
#  'ICICIFMCG',
#  'ICICIGI',
#  'ICICIGINAV',
#  'ICICIGOLD',
#  'ICICIINFRA',
#  'ICICIKINAV',
#  'ICICILINAV',
#  'ICICILIQ',
#  'ICICILOVOL',
#  'ICICIM150',
#  'ICICIMCAP',
#  'ICICIMINAV',
#  'ICICIMOM30',
#  'ICICINF100',
#  'ICICINIFTY',
#  'ICICININAV',
#  'ICICINV20',
#  'ICICINXT50',
#  'ICICIOINAV',
#  'ICICIPHARM',
#  'ICICIPINAV',
#  'ICICIPRULI',
#  'ICICIQINAV',
#  'ICICIRINAV',
#  'ICICISENSX',
#  'ICICISILVE',
#  'ICICISINAV',
#  'ICICITECH',
#  'ICICITINAV',
#  'ICICIXINAV',
#  'ICICIYINAV',
#  'ICICMOINAV',
#  'ICIL',
#  'ICINFRINAV',
#  'ICISECINAV',
#  'ICISENINAV',
#  'ICRA',
#  'IDBI',
#  'IDBIGOINAV',
#  'IDBIGOLD',
#  'IDEA',
#  'IDFC',
#  'IDFCFIRSTB',
#  'IDFNIFINAV',
#  'IDFNIFTYET',
#  'IEX',
#  'IFBAGRO',
#  'IFBIND',
#  'IFCI',
#  'IFGLEXPOR',
#  'IGARASHI',
#  'IGL',
#  'IGPL',
#  'IIFL',
#  'IIFLSEC',
#  'IIFLWAM',
#  'IITL',
#  'IMAGICAA-BE',
#  'IMFA',
#  'IMPAL',
#  'IMPEXFERRO',
#  'INCREDIBLE',
#  'INDBANK',
#  'INDHOTEL',
#  'INDIACEM',
#  'INDIAGLYCO',
#  'INDIAMART',
#  'INDIANB',
#  'INDIANCARD',
#  'INDIANHUME',
#  'INDIGO',
#  'INDIGOPNTS',
#  'INDLMETER-BE',
#  'INDNIPPON',
#  'INDOAMIN',
#  'INDOBORAX',
#  'INDOCO',
#  'INDORAMA',
#  'INDOSTAR-BE',
#  'INDOTECH',
#  'INDOTHAI',
#  'INDOWIND-BE',
#  'INDRAMEDCO',
#  'INDSWFTLAB',
#  'INDSWFTLTD',
#  'INDTERRAIN',
#  'INDUSINDBK',
#  'INDUSTOWER',
#  'INEOSSTYRO',
#  'INFIBEAM',
#  'INFOBEAN',
#  'INFOMEDIA-BE',
#  'INFRABEES',
#  'INFY',
#  'INGERRAND',
#  'INOXLEISUR',
#  'INOXWIND',
#  'INSECTICID',
#  'INSPIRISYS',
#  'INTELLECT',
#  'INTENTECH',
#  'INTLCONV',
#  'INVENTURE',
#  'IOB',
#  'IOC',
#  'IOLCP',
#  'IONEXCHANG',
#  'IPCALAB',
#  'IPL',
#  'IRB',
#  'IRCON',
#  'IRCTC',
#  'IRFC',
#  'IRIS',
#  'IRISDOREME',
#  'ISEC',
#  'ISFT',
#  'ISGEC',
#  'ISMTLTD',
#  'ITBEES',
#  'ITBEESINAV',
#  'ITC',
#  'ITDC',
#  'ITDCEM',
#  'ITI',
#  'IVC',
#  'IVP',
#  'IVZINGINAV',
#  'IVZINGOLD',
#  'IVZINNIFTY',
#  'IVZINNINAV',
#  'IWEL',
#  'IZMO',
#  'J&KBANK',
#  'JAGRAN',
#  'JAGSNPHARM',
#  'JAIBALAJI',
#  'JAICORPLTD',
#  'JAIPURKURT',
#  'JAMNAAUTO',
#  'JASH',
#  'JAYAGROGN',
#  'JAYBARMARU',
#  'JAYNECOIND',
#  'JAYSREETEA',
#  'JBCHEPHARM',
#  'JBFIND',
#  'JBMA',
#  'JCHAC',
#  'JETFREIGHT',
#  'JHS',
#  'JINDALPHOT',
#  'JINDALPOLY',
#  'JINDALSAW',
#  'JINDALSTEL',
#  'JINDRILL',
#  'JINDWORLD',
#  'JISLDVREQS',
#  'JISLJALEQS',
#  'JITFINFRA-BE',
#  'JKCEMENT',
#  'JKIL',
#  'JKLAKSHMI',
#  'JKPAPER',
#  'JKTYRE',
#  'JMA',
#  'JMCPROJECT',
#  'JMFINANCIL',
#  'JOCIL',
#  'JPASSOCIAT',
#  'JPOLYINVST',
#  'JPPOWER',
#  'JSL',
#  'JSLHISAR',
#  'JSWENERGY',
#  'JSWHL',
#  'JSWISPL',
#  'JSWSTEEL',
#  'JTEKTINDIA',
#  'JTLINFRA',
#  'JUBLFOOD',
#  'JUBLINDS-BE',
#  'JUBLINGREA',
#  'JUBLPHARMA',
#  'JUNIORBEES',
#  'JUSTDIAL',
#  'JWL-BE',
#  'JYOTHYLAB',
#  'KABRAEXTRU',
#  'KAJARIACER',
#  'KAKATCEM',
#  'KALPATPOWR',
#  'KALYANI-BE',
#  'KALYANIFRG-BE',
#  'KALYANKJIL',
#  'KAMATHOTEL-BE',
#  'KAMDHENU-BE',
#  'KANANIIND',
#  'KANORICHEM',
#  'KANPRPLA',
#  'KANSAINER',
#  'KAPSTON',
#  'KARMAENG-BE',
#  'KARURVYSYA',
#  'KAUSHALYA',
#  'KAVVERITEL',
#  'KAYA',
#  'KBCGLOBAL-BE',
#  'KCP',
#  'KCPSUGIND',
#  'KDDL',
#  'KEC',
#  'KECL',
#  'KEEPLEARN-BE',
#  'KEI',
#  'KELLTONTEC',
#  'KENNAMET',
#  'KERNEX-BE',
#  'KESORAMIND',
#  'KEYFINSERV',
#  ...]

# %%
from src.extract_tools.extract_instruments import get_nse_equities, get_nse_options_subset, get_nse_futures

# %%
eq = get_nse_equities()

# %%
print(eq[:, f.instrument_token].nunique()), eq[:, f.instrument_token].shape
# Out:
#    | instrument_token
#    |            int64
# -- + ----------------
#  0 |             2144
# [1 row x 1 column]
# (None, (2144, 1))

# %%
fut = get_nse_futures()

# %%
fut
# Out:
# <Frame#134e966f0 602x10>

# %%
fut['instrument_token'].nunique()
# Out:
# <Frame#134ea3ab0 1x1>

# %%
opt = get_nse_options_subset()
print(opt)
opt['instrument_token'].nunique()
# Out:
#      | instrument_token  exchange_token  tradingsymbol         expiry       strike  tick_size  lot_size  instrument_type  segment  exchange  underlying_tradingsymbol
#      |            int32  str32           str32                 date32      float64    float64     int32  str32            str32    str32     str32
# ---- + ----------------  --------------  --------------------  ----------  -------  ---------  --------  ---------------  -------  --------  ------------------------
#    0 |         12556802  49050           NIFTY22SEP10000CE     2022-09-29    10000       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#    1 |         12557058  49051           NIFTY22SEP10000PE     2022-09-29    10000       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#    2 |         14256386  55689           NIFTY22SEP11000CE     2022-09-29    11000       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#    3 |         14256642  55690           NIFTY22SEP11000PE     2022-09-29    11000       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#    4 |         14999298  58591           NIFTY22SEP12000CE     2022-09-29    12000       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#    5 |         14999554  58592           NIFTY22SEP12000PE     2022-09-29    12000       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#    6 |         14999810  58593           NIFTY22SEP13000CE     2022-09-29    13000       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#    7 |         15000066  58594           NIFTY22SEP13000PE     2022-09-29    13000       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#    8 |         14041858  54851           NIFTY22SEP14000CE     2022-09-29    14000       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#    9 |         14042114  54852           NIFTY22SEP14000PE     2022-09-29    14000       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#   10 |         18167042  70965           NIFTY22SEP14200PE     2022-09-29    14200       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#   11 |         18167298  70966           NIFTY22SEP14250CE     2022-09-29    14250       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#   12 |         18167554  70967           NIFTY22SEP14250PE     2022-09-29    14250       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#   13 |         18167810  70968           NIFTY22SEP14300CE     2022-09-29    14300       0.05        50  CE               NFO-OPT  NFO       NIFTY 50
#   14 |         18169602  70975           NIFTY22SEP14300PE     2022-09-29    14300       0.05        50  PE               NFO-OPT  NFO       NIFTY 50
#    … |                …  …               …                     …                 …          …         …  …                …        …         …
# 4848 |         16027138  62606           ADANIPORTS22NOV970PE  2022-11-24      970       0.05      1250  PE               NFO-OPT  NFO       ADANIPORTS
# 4849 |         16027394  62607           ADANIPORTS22NOV980CE  2022-11-24      980       0.05      1250  CE               NFO-OPT  NFO       ADANIPORTS
# 4850 |         16027650  62608           ADANIPORTS22NOV980PE  2022-11-24      980       0.05      1250  PE               NFO-OPT  NFO       ADANIPORTS
# 4851 |         16027906  62609           ADANIPORTS22NOV990CE  2022-11-24      990       0.05      1250  CE               NFO-OPT  NFO       ADANIPORTS
# 4852 |         16028162  62610           ADANIPORTS22NOV990PE  2022-11-24      990       0.05      1250  PE               NFO-OPT  NFO       ADANIPORTS
# [4853 rows x 11 columns]
# <Frame#10f3df0c0 1x1>

# %%
eq
# Out:
# <Frame#134ed49f0 2144x7>

# %%
eq = get_nse_equities()[:,f['instrument_token', 'tradingsymbol', 'exchange']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dn/d1kkpq_10w9747y6j9py79h00000gn/T/ipykernel_6771/3606447482.py in <cell line: 1>()
# ----> 1 eq = get_nse_equities()[:,f['instrument_token', 'tradingsymbol', 'exchange']]
#
# NameError: name 'get_nse_equities' is not defined

# %%
for token in eq['instrument_token'].to_list()[0][0:1]:
    print(token)
    kite.historical_data(token, )
# Out:
# 264713

# %%
from datetime import date, timedelta
dictionary = {
    'instrument_token': '738561',
    'from_date': date(2001, 1,1),
    'to_date': date(2007,12,31),
    'interval': 'day',
    # 'continuous': True,
    'oi': True,
}

# kite.historical_data(**dictionary)

# %%
from time import sleep
from datetime import date, timedelta
from datatable import Frame, dt, f
from src.utils.storage_utils import save, load
from src.extract_tools.extract_instruments import get_nse_equities, get_nse_options_subset, get_nse_futures

eq = get_nse_equities()[:, f['instrument_token', 'tradingsymbol', 'exchange', 'name']]
eq.key = 'instrument_token'
interval = 'day'
for token in eq['instrument_token'].to_list()[0][0:1]:
    chart_data = []
    for year in range(2000,2022,5):
        from_date = date(year, 1, 1)
        to_date = min(date(year+4, 12, 31), date.today() - timedelta(days=1))
        sleep(0.5)
        chart_data.extend(kite.historical_data(token, from_date, to_date, interval))
    data = Frame(chart_data)
    data['instrument_token'] = token
    save(
        data[:,:, dt.join(eq)], 
        eq[f.instrument_token == token, f.tradingsymbol].to_list()[0][0],
        'equities'
    )
# Out:
# 2022-09-29 23:14:45,677 - [INFO] - src.utils.storage_utils -     (storage_utils.py).save(28) - equities/21STCENMGM write completed

# %%
min(date(2020+4,12,31), date.today() - timedelta(days=1))
# Out:
# datetime.date(2022, 9, 28)

# %% [markdown]
# # Get latest equities

# %%
from time import sleep
from datetime import date, timedelta
from datatable import Frame, dt, f
from src.utils.storage_utils import save, load
from src.extract_tools.extract_instruments import get_nse_equities, get_nse_options_subset, get_nse_futures

eq = get_nse_equities()[:, f['instrument_token',
                             'tradingsymbol', 'exchange', 'name']]
eq = eq[:, f[:].extend({'exchange_tradingsymbol': f.exchange+':'+f.tradingsymbol})]
list_of_inputs = eq['exchange_tradingsymbol'].to_list()[0]
# Out:
# 2022-10-02 14:10:45,201 - [INFO] - src.utils.storage_utils -     (storage_utils.py).load(59) - instruments/instruments20221002 does not exist
# 2022-10-02 14:10:50,161 - [INFO] - src.utils.storage_utils -     (storage_utils.py).save(28) - instruments/instruments20221002 write completed

# %%
quotes_data = {}
for i in range(0, len(list_of_inputs), 400):
    quotes_data.update(kite.quote(*list_of_inputs[i:i+400]))
    sleep(0.5)
quotes_data
# eq.key = 'instrument_token'
# Out:
# {'NSE:20MICRONS': {'instrument_token': 4331777,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 43, 32),
#   'last_price': 97.75,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 78.2,
#   'upper_circuit_limit': 117.3,
#   'ohlc': {'open': 95.5, 'high': 99.3, 'low': 95.5, 'close': 96.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:21STCENMGM': {'instrument_token': 1025,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 23, 56),
#   'last_price': 23.3,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 22.85,
#   'upper_circuit_limit': 23.75,
#   'ohlc': {'open': 23.4, 'high': 23.4, 'low': 23.3, 'close': 23.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:3IINFOLTD': {'instrument_token': 1595393,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 47, 27),
#   'last_price': 43.85,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 35.1,
#   'upper_circuit_limit': 52.6,
#   'ohlc': {'open': 44, 'high': 44.5, 'low': 40.2, 'close': 43.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:3MINDIA': {'instrument_token': 121345,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 41, 9),
#   'last_price': 24606.3,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 19685.05,
#   'upper_circuit_limit': 29527.55,
#   'ohlc': {'open': 23900, 'high': 24850, 'low': 23821.9, 'close': 24086.55},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:3PLAND': {'instrument_token': 664321,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 28, 14),
#   'last_price': 16.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 15.9,
#   'upper_circuit_limit': 17.5,
#   'ohlc': {'open': 16.3, 'high': 17.45, 'low': 16.3, 'close': 16.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:4THDIM': {'instrument_token': 2781441,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 10, 3, 53),
#   'last_price': 54.25,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 51.55,
#   'upper_circuit_limit': 56.95,
#   'ohlc': {'open': 54.25, 'high': 54.25, 'low': 54.25, 'close': 51.7},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:5PAISA': {'instrument_token': 113921,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 51, 3),
#   'last_price': 338.15,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 270.55,
#   'upper_circuit_limit': 405.75,
#   'ohlc': {'open': 334, 'high': 342, 'low': 330.2, 'close': 333.05},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:63MOONS': {'instrument_token': 3038209,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 45, 15),
#   'last_price': 161.05,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 144.95,
#   'upper_circuit_limit': 177.15,
#   'ohlc': {'open': 157.1, 'high': 166.85, 'low': 157.1, 'close': 162.25},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:A2ZINFRA': {'instrument_token': 5351937,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 57),
#   'last_price': 10.3,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 9.3,
#   'upper_circuit_limit': 11.3,
#   'ohlc': {'open': 10.35, 'high': 10.8, 'low': 10.15, 'close': 10.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AAKASH': {'instrument_token': 60161,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 46),
#   'last_price': 13,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 12.35,
#   'upper_circuit_limit': 13.65,
#   'ohlc': {'open': 13.2, 'high': 13.6, 'low': 12.6, 'close': 13},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AAREYDRUGS': {'instrument_token': 1342721,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 41, 37),
#   'last_price': 38.85,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 31.1,
#   'upper_circuit_limit': 46.6,
#   'ohlc': {'open': 39, 'high': 40.4, 'low': 38.25, 'close': 39},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARON-BE': {'instrument_token': 265217,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 50),
#   'last_price': 155.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 147.95,
#   'upper_circuit_limit': 163.45,
#   'ohlc': {'open': 150.1, 'high': 163.8, 'low': 150.1, 'close': 156.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARTIDRUGS': {'instrument_token': 1147137,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 33),
#   'last_price': 468.75,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 375,
#   'upper_circuit_limit': 562.5,
#   'ohlc': {'open': 460, 'high': 477.95, 'low': 454.6, 'close': 463.9},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARTIIND': {'instrument_token': 1793,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 56, 17),
#   'last_price': 745.05,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 670.55,
#   'upper_circuit_limit': 819.55,
#   'ohlc': {'open': 733.85, 'high': 749.7, 'low': 725.05, 'close': 733.85},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARTISURF': {'instrument_token': 4923649,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 43, 40),
#   'last_price': 764.45,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 611.6,
#   'upper_circuit_limit': 917.3,
#   'ohlc': {'open': 766.75, 'high': 779.95, 'low': 750.35, 'close': 759.2},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARVEEDEN': {'instrument_token': 3525377,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 51, 11),
#   'last_price': 25.1,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 20.1,
#   'upper_circuit_limit': 30.1,
#   'ohlc': {'open': 25.2, 'high': 25.7, 'low': 24.65, 'close': 25.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AARVI': {'instrument_token': 4882689,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 1),
#   'last_price': 153.3,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 138,
#   'upper_circuit_limit': 168.6,
#   'ohlc': {'open': 143.75, 'high': 156.8, 'low': 140.35, 'close': 143.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AAVAS': {'instrument_token': 1378561,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 44, 42),
#   'last_price': 2241.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 1793.4,
#   'upper_circuit_limit': 2690,
#   'ohlc': {'open': 2157.4, 'high': 2270, 'low': 2150.7, 'close': 2161.5},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABAN': {'instrument_token': 2561,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 47, 29),
#   'last_price': 50.75,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 40.6,
#   'upper_circuit_limit': 60.9,
#   'ohlc': {'open': 50.1, 'high': 51.5, 'low': 50, 'close': 50.1},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABB': {'instrument_token': 3329,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 54, 40),
#   'last_price': 3088.4,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 2779.6,
#   'upper_circuit_limit': 3397.2,
#   'ohlc': {'open': 3014.85, 'high': 3155, 'low': 2992, 'close': 2996.2},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABBOTINDIA': {'instrument_token': 4583169,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 51, 44),
#   'last_price': 19139.15,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 17225.25,
#   'upper_circuit_limit': 21053.05,
#   'ohlc': {'open': 19020, 'high': 19299, 'low': 18818, 'close': 19181.1},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABCAPITAL': {'instrument_token': 5533185,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 54),
#   'last_price': 111.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 100.65,
#   'upper_circuit_limit': 122.95,
#   'ohlc': {'open': 109.05, 'high': 112.45, 'low': 108.4, 'close': 109.7},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABFRL': {'instrument_token': 7707649,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 52, 49),
#   'last_price': 349.1,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 314.2,
#   'upper_circuit_limit': 384,
#   'ohlc': {'open': 338.9, 'high': 351.75, 'low': 334, 'close': 338.15},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABMINTLLTD-BE': {'instrument_token': 1421057,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 11, 20, 49),
#   'last_price': 74.75,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 71.05,
#   'upper_circuit_limit': 78.45,
#   'ohlc': {'open': 74.75, 'high': 74.75, 'low': 74.75, 'close': 76.25},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABSLAMC': {'instrument_token': 1540609,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 44, 12),
#   'last_price': 455,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 409.5,
#   'upper_circuit_limit': 500.5,
#   'ohlc': {'open': 452, 'high': 455.9, 'low': 450.05, 'close': 453.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABSLBAINAV': {'instrument_token': 2550785,
#   'timestamp': datetime.datetime(2022, 9, 30, 16, 56, 30),
#   'last_trade_time': datetime.datetime(1970, 1, 1, 5, 30),
#   'last_price': 0,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 90,
#   'upper_circuit_limit': 110,
#   'ohlc': {'open': 0, 'high': 0, 'low': 0, 'close': 0},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABSLBANETF': {'instrument_token': 3580673,
#   'timestamp': datetime.datetime(2022, 9, 30, 18, 11, 36),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 2),
#   'last_price': 38.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 30.16,
#   'upper_circuit_limit': 45.24,
#   'ohlc': {'open': 37.99, 'high': 38.98, 'low': 37.31, 'close': 37.7},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABSLNN50ET': {'instrument_token': 1878785,
#   'timestamp': datetime.datetime(2022, 9, 30, 18, 11, 36),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 52),
#   'last_price': 43.62,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 34.43,
#   'upper_circuit_limit': 51.63,
#   'ohlc': {'open': 43.2, 'high': 43.85, 'low': 42.3, 'close': 43.08},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ABSLNNINAV': {'instrument_token': 2553089,
#   'timestamp': datetime.datetime(2022, 9, 30, 16, 56, 30),
#   'last_trade_time': datetime.datetime(1970, 1, 1, 5, 30),
#   'last_price': 0,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 90,
#   'upper_circuit_limit': 110,
#   'ohlc': {'open': 0, 'high': 0, 'low': 0, 'close': 0},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ACC': {'instrument_token': 5633,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 13),
#   'last_price': 2415.65,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 2174.1,
#   'upper_circuit_limit': 2657.2,
#   'ohlc': {'open': 2370, 'high': 2428, 'low': 2360.4, 'close': 2374.05},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ACCELYA': {'instrument_token': 1805569,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 12),
#   'last_price': 1125.85,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 900.7,
#   'upper_circuit_limit': 1351,
#   'ohlc': {'open': 1120.2, 'high': 1133.45, 'low': 1115.35, 'close': 1120.15},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ACCURACY': {'instrument_token': 375041,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 56),
#   'last_price': 260.65,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 208.55,
#   'upper_circuit_limit': 312.75,
#   'ohlc': {'open': 265.1, 'high': 269.45, 'low': 258, 'close': 259.8},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ACE': {'instrument_token': 3478273,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 58, 25),
#   'last_price': 275.15,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 220.15,
#   'upper_circuit_limit': 330.15,
#   'ohlc': {'open': 273.8, 'high': 278.8, 'low': 270.75, 'close': 273.75},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ACRYSIL': {'instrument_token': 481025,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 29),
#   'last_price': 609.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 487.8,
#   'upper_circuit_limit': 731.6,
#   'ohlc': {'open': 597, 'high': 619.8, 'low': 585.1, 'close': 589.5},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADANIENT': {'instrument_token': 6401,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 46),
#   'last_price': 3455.75,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 3110.2,
#   'upper_circuit_limit': 3801.3,
#   'ohlc': {'open': 3447.95, 'high': 3523.8, 'low': 3371.1, 'close': 3470.7},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADANIGREEN': {'instrument_token': 912129,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 42),
#   'last_price': 2260.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 1808.65,
#   'upper_circuit_limit': 2712.95,
#   'ohlc': {'open': 2003.9, 'high': 2404.85, 'low': 1995.2, 'close': 2004.05},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADANIPORTS': {'instrument_token': 3861249,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 11),
#   'last_price': 820.65,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 738.6,
#   'upper_circuit_limit': 902.7,
#   'ohlc': {'open': 822.5, 'high': 830.45, 'low': 801, 'close': 816.4},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADANIPOWER-BE': {'instrument_token': 4452353,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 56, 32),
#   'last_price': 373.5,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 354.85,
#   'upper_circuit_limit': 392.15,
#   'ohlc': {'open': 366, 'high': 376, 'low': 366, 'close': 369.45},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADANITRANS': {'instrument_token': 2615553,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 55, 23),
#   'last_price': 3289.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 2631.85,
#   'upper_circuit_limit': 3947.75,
#   'ohlc': {'open': 3350, 'high': 3417.45, 'low': 3232, 'close': 3406.4},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADFFOODS': {'instrument_token': 5058817,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 17),
#   'last_price': 733.6,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 586.9,
#   'upper_circuit_limit': 880.3,
#   'ohlc': {'open': 706, 'high': 776.1, 'low': 704.1, 'close': 716.65},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADL-BE': {'instrument_token': 63489,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 26, 3),
#   'last_price': 72.85,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 69.25,
#   'upper_circuit_limit': 76.45,
#   'ohlc': {'open': 70.6, 'high': 74.1, 'low': 67.65, 'close': 70.6},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADORWELD': {'instrument_token': 8705,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 7),
#   'last_price': 914.3,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 731.45,
#   'upper_circuit_limit': 1097.15,
#   'ohlc': {'open': 903, 'high': 926, 'low': 903, 'close': 913.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADROITINFO': {'instrument_token': 1267969,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 56),
#   'last_price': 17.4,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 16.55,
#   'upper_circuit_limit': 18.25,
#   'ohlc': {'open': 17.35, 'high': 17.9, 'low': 16.5, 'close': 17.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADSL': {'instrument_token': 3792129,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 52, 10),
#   'last_price': 103.45,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 82.8,
#   'upper_circuit_limit': 124.1,
#   'ohlc': {'open': 103.9, 'high': 105, 'low': 102.55, 'close': 103.15},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADVANIHOTR': {'instrument_token': 3774721,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 27, 32),
#   'last_price': 80.95,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 64.8,
#   'upper_circuit_limit': 97.1,
#   'ohlc': {'open': 80.7, 'high': 82.75, 'low': 80.05, 'close': 80.7},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ADVENZYMES': {'instrument_token': 4617985,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 22),
#   'last_price': 269.35,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 215.5,
#   'upper_circuit_limit': 323.2,
#   'ohlc': {'open': 273.25, 'high': 274.85, 'low': 266.95, 'close': 271.9},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AEGISCHEM': {'instrument_token': 10241,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 49, 28),
#   'last_price': 271.1,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 216.9,
#   'upper_circuit_limit': 325.3,
#   'ohlc': {'open': 262.8, 'high': 273.8, 'low': 260.2, 'close': 262.8},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AETHER': {'instrument_token': 2511361,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 56),
#   'last_price': 913,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 821.7,
#   'upper_circuit_limit': 1004.3,
#   'ohlc': {'open': 912.65, 'high': 930, 'low': 902.3, 'close': 912.65},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:AFFLE': {'instrument_token': 2903809,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 49),
#   'last_price': 1261.15,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 1008.95,
#   'upper_circuit_limit': 1513.35,
#   'ohlc': {'open': 1203, 'high': 1268.4, 'low': 1200, 'close': 1209.6},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
# ...
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITBEES': {'instrument_token': 4885505,
#   'timestamp': datetime.datetime(2022, 9, 30, 18, 11, 36),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 59, 38),
#   'last_price': 27.94,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 22.23,
#   'upper_circuit_limit': 33.33,
#   'ohlc': {'open': 27.94, 'high': 28.04, 'low': 27.45, 'close': 27.85},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITBEESINAV': {'instrument_token': 2596097,
#   'timestamp': datetime.datetime(2022, 9, 30, 16, 56, 30),
#   'last_trade_time': datetime.datetime(1970, 1, 1, 5, 30),
#   'last_price': 27.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 90,
#   'upper_circuit_limit': 110,
#   'ohlc': {'open': 0, 'high': 0, 'low': 0, 'close': 27.78},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITC': {'instrument_token': 424961,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 51),
#   'last_price': 332.2,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 299,
#   'upper_circuit_limit': 365.4,
#   'ohlc': {'open': 333.05, 'high': 335.75, 'low': 330.15, 'close': 333.05},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITDC': {'instrument_token': 4940545,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 44, 36),
#   'last_price': 350,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 280,
#   'upper_circuit_limit': 420,
#   'ohlc': {'open': 345.7, 'high': 355.8, 'low': 342.5, 'close': 346.1},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITDCEM': {'instrument_token': 1439233,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 42, 3),
#   'last_price': 113.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 91.05,
#   'upper_circuit_limit': 136.55,
#   'ohlc': {'open': 112.2, 'high': 115.65, 'low': 110.1, 'close': 112.25},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:ITI': {'instrument_token': 428801,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 14),
#   'last_price': 105.45,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 84.4,
#   'upper_circuit_limit': 126.5,
#   'ohlc': {'open': 105, 'high': 107.5, 'low': 103.65, 'close': 106.85},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVC': {'instrument_token': 1718017,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 55, 30),
#   'last_price': 8.8,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 7.05,
#   'upper_circuit_limit': 10.55,
#   'ohlc': {'open': 9.1, 'high': 9.15, 'low': 8.75, 'close': 9},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVP': {'instrument_token': 430337,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 37),
#   'last_price': 144.5,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 115.6,
#   'upper_circuit_limit': 173.4,
#   'ohlc': {'open': 145, 'high': 146.9, 'low': 143.55, 'close': 144.6},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVZINGINAV': {'instrument_token': 2108417,
#   'timestamp': datetime.datetime(2022, 9, 30, 16, 56, 27),
#   'last_trade_time': datetime.datetime(1970, 1, 1, 5, 30),
#   'last_price': 4523.25,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 3619.72,
#   'upper_circuit_limit': 5429.58,
#   'ohlc': {'open': 0, 'high': 0, 'low': 0, 'close': 4462.5},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVZINGOLD': {'instrument_token': 4682753,
#   'timestamp': datetime.datetime(2022, 9, 30, 18, 11, 36),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 29, 53),
#   'last_price': 4519.9,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 3576.9,
#   'upper_circuit_limit': 5365.3,
#   'ohlc': {'open': 4504.8, 'high': 4520.05, 'low': 4490, 'close': 4462.5},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVZINNIFTY': {'instrument_token': 6199553,
#   'timestamp': datetime.datetime(2022, 9, 30, 18, 11, 36),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 13, 22, 2),
#   'last_price': 1888.9,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 1482.66,
#   'upper_circuit_limit': 2223.98,
#   'ohlc': {'open': 1860.6, 'high': 1888.9, 'low': 1860.6, 'close': 1861.65},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IVZINNINAV': {'instrument_token': 2578177,
#   'timestamp': datetime.datetime(2022, 9, 30, 16, 56, 30),
#   'last_trade_time': datetime.datetime(1970, 1, 1, 5, 30),
#   'last_price': 1882.41,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 90,
#   'upper_circuit_limit': 110,
#   'ohlc': {'open': 0, 'high': 0, 'low': 0, 'close': 1869.1},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IWEL': {'instrument_token': 966657,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 26, 37),
#   'last_price': 939.05,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 892.1,
#   'upper_circuit_limit': 986,
#   'ohlc': {'open': 934.85, 'high': 939.05, 'low': 912.25, 'close': 894.35},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:IZMO': {'instrument_token': 3628545,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 47, 19),
#   'last_price': 70.55,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 56.45,
#   'upper_circuit_limit': 84.65,
#   'ohlc': {'open': 70.35, 'high': 72.7, 'low': 70.25, 'close': 70.65},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:J&KBANK': {'instrument_token': 1442049,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 58, 51),
#   'last_price': 27.7,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 22.2,
#   'upper_circuit_limit': 33.2,
#   'ohlc': {'open': 27.15, 'high': 28.2, 'low': 27, 'close': 27.1},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  'NSE:JAGRAN': {'instrument_token': 3382017,
#   'timestamp': datetime.datetime(2022, 9, 30, 20, 47, 2),
#   'last_trade_time': datetime.datetime(2022, 9, 30, 15, 57, 55),
#   'last_price': 64.95,
#   'last_quantity': 0,
#   'buy_quantity': 0,
#   'sell_quantity': 0,
#   'volume': 0,
#   'average_price': 0,
#   'oi': 0,
#   'oi_day_high': 0,
#   'oi_day_low': 0,
#   'net_change': 0,
#   'lower_circuit_limit': 52,
#   'upper_circuit_limit': 77.9,
#   'ohlc': {'open': 62.7, 'high': 65.6, 'low': 62.7, 'close': 63.3},
#   'depth': {'buy': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}],
#    'sell': [{'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0},
#     {'price': 0, 'quantity': 0, 'orders': 0}]}},
#  ...}

# %%
len(quotes_data.keys())
# Out:
# 2176

# %%
for ts, quote_data in quotes_data.items():
    quote_data.update(quote_data['ohlc'])
    mapping_quote = {
        'last_price': 'close',
        'last_trade_time': 'date'
    }

    df_eq = Frame({mapping_quote.get(k,k): [v] for k, v in quote_data.items() if k in (
        'open', 'high', 'low', 'last_price', 'volume', 'last_trade_time')})
    df_eq.cbind(eq[f.exchange_tradingsymbol == ts, :])
    past_data = load(
        '21STCENMGM',
        'equities'
    )
    past_data.rbind(df_eq[:, f[:].remove(f.exchange_tradingsymbol)])
    print(df_eq)

    print(past_data.tail(3))
    
    break
# Out:
#    | date                   close  volume     open     high      low  instrument_token  tradingsymbol  exchange  name        exchange_tradingsymbol
#    | time64               float64    int8  float64  float64  float64             int32  str32          str32     str32       str32
# -- + -------------------  -------  ------  -------  -------  -------  ----------------  -------------  --------  ----------  ----------------------
#  0 | 2022-09-30T15:43:32    97.75       0     95.5     99.3     95.5           4331777  20MICRONS      NSE       20 MICRONS  NSE:20MICRONS
# [1 row x 11 columns]
#
#    | date                    open     high      low    close  volume  instrument_token  tradingsymbol  exchange  name
#    | time64               float64  float64  float64  float64   int32             int32  str32          str32     str32
# -- + -------------------  -------  -------  -------  -------  ------  ----------------  -------------  --------  -------------------------
#  0 | 2022-09-26T18:30:00    25.1      25.1    24.25    24.45   18213              1025  21STCENMGM     NSE       21ST CENTURY MGMT SERVICE
#  1 | 2022-09-27T18:30:00    24.05     24.6    24       24.2     9897              1025  21STCENMGM     NSE       21ST CENTURY MGMT SERVICE
#  2 | 2022-09-30T15:43:32    95.5      99.3    95.5     97.75       0           4331777  20MICRONS      NSE       20 MICRONS
# [3 rows x 10 columns]

# %%
past_data = load(
    '21STCENMGM',
    'equities'
)
past_data
# Out:
# <Frame#129318a20 1142x10>

# %%
interval = 'day'
for token in eq['instrument_token'].to_list()[0][0:1]:
    chart_data = []
    for year in range(2000, 2022, 5):
        from_date = date(year, 1, 1)
        to_date = min(date(year+4, 12, 31), date.today() - timedelta(days=1))
        sleep(0.5)
        chart_data.extend(kite.historical_data(
            token, from_date, to_date, interval))
    data = Frame(chart_data)
    data['instrument_token'] = token
    save(
        data[:, :, dt.join(eq)],
        eq[f.instrument_token == token, f.tradingsymbol].to_list()[0][0],
        'equities'
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dn/d1kkpq_10w9747y6j9py79h00000gn/T/ipykernel_8510/421099557.py in <cell line: 2>()
#      11     data['instrument_token'] = token
#      12     save(
# ---> 13         data[:, :, dt.join(eq)],
#      14         eq[f.instrument_token == token, f.tradingsymbol].to_list()[0][0],
#      15         'equities'
#
# ValueError: The join frame is not keyed

# %%
eq.to_pandas().apply(lambda x:x)
# Out:
#       instrument_token      tradingsymbol exchange                  name
# 0               264713  HANGSENG BEES-NAV      NSE     HANGSENG BEES-NAV
# 1               264969          INDIA VIX      NSE             INDIA VIX
# 2               260617          NIFTY 100      NSE             NIFTY 100
# 3               264457          NIFTY 200      NSE             NIFTY 200
# 4               256265           NIFTY 50      NSE              NIFTY 50
# ...                ...                ...      ...                   ...
# 2139           2916865               ZOTA      NSE      ZOTA HEALTH CARE
# 2140           7436801              ZUARI      NSE  ZUARI AGRO CHEMICALS
# 2141            979713           ZUARIIND      NSE      ZUARI INDUSTRIES
# 2142           2029825          ZYDUSLIFE      NSE    ZYDUS LIFESCIENCES
# 2143           4514561          ZYDUSWELL      NSE        ZYDUS WELLNESS
#
# [2144 rows x 4 columns]

# %%
eq[:, f[:].extend({'exchange_tradingsymbol': f.exchange+':'+f.tradingsymbol})]
# Out:
# <Frame#12a98f240 2144x5>
